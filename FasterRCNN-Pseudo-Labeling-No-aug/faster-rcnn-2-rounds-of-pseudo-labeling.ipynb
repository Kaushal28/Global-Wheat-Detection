# %%
# %%capture
# !cp /kaggle/input/rcnnutils/engine.py .
# !cp /kaggle/input/rcnnutils/utils.py .
# !cp /kaggle/input/rcnnutils/coco_eval.py .
# !cp /kaggle/input/rcnnutils/coco_utils.py .
# !cp /kaggle/input/rcnnutils/transforms.py .
# !mkdir -p /root/.cache/torch/checkpoints
# !cp /kaggle/input/resnet50/resnet50-19c8e357.pth /root/.cache/torch/checkpoints/
# !cp /kaggle/input/pycocotools/pycocotools-2.0-cp37-cp37m-linux_x86_64.whl .
# !pip install pycocotools-2.0-cp37-cp37m-linux_x86_64.whl

# %%
import os
import ast
import numpy as np
import pandas as pd

import gc
import cv2
import torch
import torchvision
from torch.utils.data import DataLoader, Dataset
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor

import matplotlib.pyplot as plt

import utils
from engine import train_one_epoch, evaluate

# %%
DATA_DIR = '/kaggle/input/global-wheat-detection'
DEVICE = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
BATCH_SIZE = 16
DETECTION_THRESHOLD = 0.50

# %%
def get_train_df():
    train_df = pd.read_csv(os.path.join(DATA_DIR, 'train.csv'))

    # Let's expand the bounding box coordinates and calculate the area of all the bboxes
    train_df[['x_min','y_min', 'width', 'height']] = pd.DataFrame([ast.literal_eval(x) for x in train_df.bbox.tolist()], index= train_df.index)
    train_df = train_df[['image_id', 'bbox', 'source', 'x_min', 'y_min', 'width', 'height']]
    train_df = train_df.drop(['bbox', 'source'], axis=1)
    return train_df
train_df = get_train_df()

# %%
# train_df = train_df.iloc[:2000]

# %%
sample_sub_df = pd.read_csv(os.path.join(DATA_DIR, 'sample_submission.csv'))
sample_sub_df
# Out:
#     image_id PredictionString
# 0  aac893a91    1.0 0 0 50 50
# 1  51f1be19e    1.0 0 0 50 50
# 2  f5a1f0358    1.0 0 0 50 50
# 3  796707dd7    1.0 0 0 50 50
# 4  51b3e36ab    1.0 0 0 50 50
# 5  348a992bb    1.0 0 0 50 50
# 6  cc3532ff6    1.0 0 0 50 50
# 7  2fd875eaa    1.0 0 0 50 50
# 8  cb8d261a3    1.0 0 0 50 50
# 9  53f253011    1.0 0 0 50 50

# %%
def get_model(pre_trained=True):
    # load a model pre-trained pre-trained on COCO
    model = torchvision.models.detection.fasterrcnn_resnet50_fpn(pretrained=pre_trained)

    # replace the classifier with a new one, that has
    # num_classes which is user-defined
    num_classes = 2  # 1 class (wheat heads) + background

    # get number of input features for the classifier
    in_features = model.roi_heads.box_predictor.cls_score.in_features

    # replace the pre-trained head with a new one
    model.roi_heads.box_predictor = FastRCNNPredictor(in_features, num_classes)

    return model

# %%
# %%capture
model = get_model(pre_trained=False)
model.to(DEVICE)
model.load_state_dict(torch.load(f'/kaggle/input/wheatdetectionfasterrcnn/seresnext_ls_fold0.pth', map_location=DEVICE))

# Setting model in evaluation mode for getting pseudo labels
model.eval()

# %%
class WheatDatasetTest(Dataset):
    
    def __init__(self, image_ids):
        self.image_ids = image_ids
    
    def __len__(self):
        return len(self.image_ids)
    
    def __getitem__(self, index):
        image_id = self.image_ids[index][:-4]
        image = cv2.imread(os.path.join(DATA_DIR, 'test', f'{image_id}.jpg'), cv2.IMREAD_COLOR)
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB).astype(np.float32)
        image /= 255.0
        # Convert from NHWC to NCHW as pytorch expects images in NCHW format
        image = np.transpose(image, (2, 0, 1))
        image = torch.from_numpy(image)

        return image_id, image

# %%
def collate_fn(batch):
    return tuple(zip(*batch))


def format_prediction_string(boxes, scores):
    pred_strings = []
    for j in zip(scores, boxes):
        pred_strings.append("{0:.4f} {1} {2} {3} {4}".format(j[0], j[1][0], j[1][1], j[1][2], j[1][3]))

    return " ".join(pred_strings)

# %% [markdown]
# ## Predict on unseen test dataset and get the labels

# %%
def get_pseudo_labels(test_data_loader):
    model.eval()
    model.to(DEVICE)
    pseudo_labels = []

    for image_ids, images in test_data_loader:

        images = list(image.to(DEVICE) for image in images)
        outputs = model(images)

        for i, image in enumerate(images):

            boxes = outputs[i]['boxes'].data.cpu().numpy()
            scores = outputs[i]['scores'].data.cpu().numpy()

            boxes = boxes[scores >= DETECTION_THRESHOLD].astype(np.int32)
            scores = scores[scores >= DETECTION_THRESHOLD]
            image_id = image_ids[i]

            boxes[:, 2] = boxes[:, 2] - boxes[:, 0]
            boxes[:, 3] = boxes[:, 3] - boxes[:, 1]

            for box in boxes:
                pseudo_labels.append({
                'image_id': image_id,
                'x_min': box[0],
                'y_min': box[1],
                'width': box[2],
                'height': box[3]
            })
    pseudo_train_df = pd.DataFrame(pseudo_labels)
    return pseudo_train_df

# %%
test_dataset = WheatDatasetTest(os.listdir(os.path.join(DATA_DIR, 'test')))

test_data_loader = DataLoader(
    test_dataset,
    batch_size=4,
    shuffle=False,
    num_workers=4,
    drop_last=False,
    collate_fn=collate_fn
)

# %%
pseudo_train_df = get_pseudo_labels(test_data_loader)

# %% [markdown]
# ## We got pseudo labels! Now let's retrain the same model with all the training data as well as all the pseudo labels

# %%
train_df = pd.concat([train_df, pseudo_train_df]).reset_index(drop=True)
train_df.tail()
# Out:
#          image_id  x_min  y_min  width  height
# 148030  53f253011  578.0  580.0   80.0   133.0
# 148031  53f253011  296.0  610.0  125.0    97.0
# 148032  53f253011  928.0  819.0   94.0   201.0
# 148033  53f253011  527.0  399.0   73.0    70.0
# 148034  53f253011  141.0  618.0   87.0   126.0

# %%
# There are some huge bounding boxes in the training dataset. Let's get rid of them
train_df = train_df[train_df['height'] * train_df['width'] < 100000].reset_index(drop=True)
train_df['area'] = train_df['width'] * train_df['height']
train_df.head()
# Out:
#     image_id  x_min  y_min  width  height     area
# 0  b6ab77fd7  834.0  222.0   56.0    36.0   2016.0
# 1  b6ab77fd7  226.0  548.0  130.0    58.0   7540.0
# 2  b6ab77fd7  377.0  504.0   74.0   160.0  11840.0
# 3  b6ab77fd7  834.0   95.0  109.0   107.0  11663.0
# 4  b6ab77fd7   26.0  144.0  124.0   117.0  14508.0

# %%
class WheatDatasetTrain(Dataset):
    def __init__(self, df):
        self.df = df
        self.image_ids = train_df['image_id'].unique()
    
    def __len__(self):
        return len(self.image_ids)
    
    def __getitem__(self, index):
        image_id = self.image_ids[index]
        
        path = os.path.join(DATA_DIR, 'train', f'{image_id}.jpg')
        if not os.path.isfile(os.path.join(DATA_DIR, 'train', f'{image_id}.jpg')):
            path = os.path.join(DATA_DIR, 'test', f'{image_id}.jpg')

        image = cv2.imread(path, cv2.IMREAD_COLOR)
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB).astype(np.float32)
        image /= 255.0
        # Convert from NHWC to NCHW as pytorch expects images in NCHW format
        image = np.transpose(image, (2, 0, 1))
        image = torch.from_numpy(image)
        
        # Get bbox coordinates for each wheat head(s)
        bboxes_df = self.df[self.df['image_id'] == image_id]
        boxes, areas = [], []
        n_objects = len(bboxes_df)  # Number of wheat heads in the given image

        for i in range(n_objects):
            x_min = bboxes_df.iloc[i]['x_min']
            x_max = x_min + bboxes_df.iloc[i]['width']
            y_min = bboxes_df.iloc[i]['y_min']
            y_max = y_min + bboxes_df.iloc[i]['height']
            boxes.append([x_min, y_min, x_max, y_max])
            areas.append(bboxes_df.iloc[i]['area'])
            
        
        # Convert everything into a torch.Tensor
        boxes = torch.as_tensor(boxes, dtype=torch.float32)
        
        # Get the labels. We have only one class (wheat head)
        labels = torch.ones((n_objects, ), dtype=torch.int64)
        
        areas = torch.as_tensor(areas)
        
        # suppose all instances are not crowd
        iscrowd = torch.zeros((n_objects, ), dtype=torch.int64)
        
        target = {
            'boxes': boxes,
            'labels': labels,
            'image_id': torch.tensor([index]),
            'area': areas,
            'iscrowd': iscrowd
        }

        return image, target

# %%
def train(train_df):
    model.train()
    model.to(DEVICE)

    # our dataset has two classes only - background and wheat heads
    num_classes = 2

    # use our dataset and defined transformations
    dataset = WheatDatasetTrain(train_df)
    dataset_test = WheatDatasetTrain(train_df)

    # split the dataset in train and test set
    indices = torch.randperm(len(dataset)).tolist()
    dataset = torch.utils.data.Subset(dataset, indices[:-50])
    dataset_test = torch.utils.data.Subset(dataset_test, indices[-50:])

    # define training and validation data loaders
    data_loader = torch.utils.data.DataLoader(
        dataset, batch_size=16, shuffle=True, num_workers=4,
        collate_fn=utils.collate_fn)

    data_loader_test = torch.utils.data.DataLoader(
        dataset_test, batch_size=16, shuffle=False, num_workers=4,
        collate_fn=utils.collate_fn)

    # construct an optimizer
    params = [p for p in model.parameters() if p.requires_grad]
    optimizer = torch.optim.SGD(params, lr=0.005,
                                momentum=0.9, weight_decay=0.0005)

    # and a learning rate scheduler
    lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer,
                                                   step_size=3,
                                                   gamma=0.1)

    # let's train it for 4 epochs
    num_epochs = 4

    for epoch in range(num_epochs):
        # train for one epoch, printing every 10 iterations
        train_one_epoch(model, optimizer, data_loader, DEVICE, epoch, print_freq=10)
        # update the learning rate
        lr_scheduler.step()
        # evaluate on the test dataset
        evaluate(model, data_loader_test, device=DEVICE)

# %%
train(train_df)
# Out:
# Epoch: [0]  [  0/209]  eta: 0:34:39  lr: 0.000029  loss: 0.6384 (0.6384)  loss_classifier: 0.2362 (0.2362)  loss_box_reg: 0.2204 (0.2204)  loss_objectness: 0.0504 (0.0504)  loss_rpn_box_reg: 0.1315 (0.1315)  time: 9.9492  data: 6.2071  max mem: 11473
# Epoch: [0]  [ 10/209]  eta: 0:09:33  lr: 0.000269  loss: 0.5273 (0.5458)  loss_classifier: 0.1907 (0.1977)  loss_box_reg: 0.1856 (0.1853)  loss_objectness: 0.0397 (0.0404)  loss_rpn_box_reg: 0.1244 (0.1223)  time: 2.8805  data: 0.6682  max mem: 11736
# Epoch: [0]  [ 20/209]  eta: 0:08:00  lr: 0.000509  loss: 0.5386 (0.5585)  loss_classifier: 0.1955 (0.2013)  loss_box_reg: 0.1856 (0.1909)  loss_objectness: 0.0397 (0.0410)  loss_rpn_box_reg: 0.1248 (0.1253)  time: 2.1718  data: 0.1090  max mem: 11736
# Epoch: [0]  [ 30/209]  eta: 0:07:08  lr: 0.000749  loss: 0.5522 (0.5537)  loss_classifier: 0.2020 (0.1995)  loss_box_reg: 0.1888 (0.1890)  loss_objectness: 0.0403 (0.0414)  loss_rpn_box_reg: 0.1237 (0.1239)  time: 2.1258  data: 0.1100  max mem: 11736
# Epoch: [0]  [ 40/209]  eta: 0:06:32  lr: 0.000990  loss: 0.5361 (0.5497)  loss_classifier: 0.1976 (0.1987)  loss_box_reg: 0.1824 (0.1884)  loss_objectness: 0.0406 (0.0404)  loss_rpn_box_reg: 0.1162 (0.1222)  time: 2.0920  data: 0.1108  max mem: 11736
# Epoch: [0]  [ 50/209]  eta: 0:06:02  lr: 0.001230  loss: 0.5533 (0.5557)  loss_classifier: 0.1958 (0.1993)  loss_box_reg: 0.1869 (0.1894)  loss_objectness: 0.0419 (0.0424)  loss_rpn_box_reg: 0.1179 (0.1246)  time: 2.1077  data: 0.1131  max mem: 11736
# Epoch: [0]  [ 60/209]  eta: 0:05:35  lr: 0.001470  loss: 0.5699 (0.5569)  loss_classifier: 0.1988 (0.1997)  loss_box_reg: 0.1882 (0.1895)  loss_objectness: 0.0467 (0.0431)  loss_rpn_box_reg: 0.1235 (0.1247)  time: 2.0983  data: 0.1133  max mem: 11736
# Epoch: [0]  [ 70/209]  eta: 0:05:09  lr: 0.001710  loss: 0.5819 (0.5606)  loss_classifier: 0.2057 (0.2010)  loss_box_reg: 0.1929 (0.1912)  loss_objectness: 0.0425 (0.0429)  loss_rpn_box_reg: 0.1280 (0.1255)  time: 2.0753  data: 0.1038  max mem: 11736
# Epoch: [0]  [ 80/209]  eta: 0:04:45  lr: 0.001950  loss: 0.5667 (0.5585)  loss_classifier: 0.2072 (0.2002)  loss_box_reg: 0.1963 (0.1911)  loss_objectness: 0.0421 (0.0424)  loss_rpn_box_reg: 0.1266 (0.1248)  time: 2.1087  data: 0.1024  max mem: 11736
# Epoch: [0]  [ 90/209]  eta: 0:04:21  lr: 0.002190  loss: 0.5644 (0.5608)  loss_classifier: 0.2003 (0.2003)  loss_box_reg: 0.1924 (0.1914)  loss_objectness: 0.0401 (0.0430)  loss_rpn_box_reg: 0.1263 (0.1261)  time: 2.1087  data: 0.1064  max mem: 11736
# Epoch: [0]  [100/209]  eta: 0:03:58  lr: 0.002430  loss: 0.5555 (0.5601)  loss_classifier: 0.1987 (0.2001)  loss_box_reg: 0.1898 (0.1909)  loss_objectness: 0.0431 (0.0434)  loss_rpn_box_reg: 0.1233 (0.1258)  time: 2.0819  data: 0.1079  max mem: 11736
# Epoch: [0]  [110/209]  eta: 0:03:36  lr: 0.002671  loss: 0.5622 (0.5620)  loss_classifier: 0.2019 (0.2008)  loss_box_reg: 0.1898 (0.1913)  loss_objectness: 0.0472 (0.0438)  loss_rpn_box_reg: 0.1254 (0.1260)  time: 2.1341  data: 0.1111  max mem: 11736
# Epoch: [0]  [120/209]  eta: 0:03:13  lr: 0.002911  loss: 0.5788 (0.5630)  loss_classifier: 0.2090 (0.2014)  loss_box_reg: 0.1951 (0.1916)  loss_objectness: 0.0466 (0.0439)  loss_rpn_box_reg: 0.1260 (0.1260)  time: 2.1287  data: 0.1120  max mem: 11736
# Epoch: [0]  [130/209]  eta: 0:02:51  lr: 0.003151  loss: 0.5762 (0.5636)  loss_classifier: 0.2062 (0.2016)  loss_box_reg: 0.1938 (0.1918)  loss_objectness: 0.0438 (0.0440)  loss_rpn_box_reg: 0.1259 (0.1262)  time: 2.0850  data: 0.1052  max mem: 11736
# Epoch: [0]  [140/209]  eta: 0:02:29  lr: 0.003391  loss: 0.5749 (0.5648)  loss_classifier: 0.2062 (0.2017)  loss_box_reg: 0.1968 (0.1925)  loss_objectness: 0.0443 (0.0443)  loss_rpn_box_reg: 0.1259 (0.1264)  time: 2.1269  data: 0.1037  max mem: 11736
# Epoch: [0]  [150/209]  eta: 0:02:07  lr: 0.003631  loss: 0.5749 (0.5666)  loss_classifier: 0.2090 (0.2023)  loss_box_reg: 0.2010 (0.1929)  loss_objectness: 0.0481 (0.0447)  loss_rpn_box_reg: 0.1259 (0.1267)  time: 2.1293  data: 0.1141  max mem: 11736
# Epoch: [0]  [160/209]  eta: 0:01:45  lr: 0.003871  loss: 0.5729 (0.5674)  loss_classifier: 0.2056 (0.2028)  loss_box_reg: 0.1955 (0.1929)  loss_objectness: 0.0463 (0.0448)  loss_rpn_box_reg: 0.1271 (0.1269)  time: 2.0774  data: 0.1151  max mem: 11736
# Epoch: [0]  [170/209]  eta: 0:01:24  lr: 0.004111  loss: 0.5680 (0.5670)  loss_classifier: 0.2003 (0.2025)  loss_box_reg: 0.1922 (0.1929)  loss_objectness: 0.0429 (0.0445)  loss_rpn_box_reg: 0.1311 (0.1271)  time: 2.1154  data: 0.1146  max mem: 11736
# Epoch: [0]  [180/209]  eta: 0:01:02  lr: 0.004352  loss: 0.5680 (0.5677)  loss_classifier: 0.2003 (0.2026)  loss_box_reg: 0.1937 (0.1934)  loss_objectness: 0.0423 (0.0446)  loss_rpn_box_reg: 0.1263 (0.1271)  time: 2.1068  data: 0.1137  max mem: 11736
# Epoch: [0]  [190/209]  eta: 0:00:40  lr: 0.004592  loss: 0.5573 (0.5670)  loss_classifier: 0.1945 (0.2024)  loss_box_reg: 0.1893 (0.1930)  loss_objectness: 0.0462 (0.0448)  loss_rpn_box_reg: 0.1235 (0.1269)  time: 2.0845  data: 0.1061  max mem: 11736
# Epoch: [0]  [200/209]  eta: 0:00:19  lr: 0.004832  loss: 0.5545 (0.5676)  loss_classifier: 0.1943 (0.2025)  loss_box_reg: 0.1888 (0.1932)  loss_objectness: 0.0442 (0.0449)  loss_rpn_box_reg: 0.1241 (0.1270)  time: 2.1379  data: 0.1110  max mem: 11736
# Epoch: [0]  [208/209]  eta: 0:00:02  lr: 0.005000  loss: 0.5663 (0.5675)  loss_classifier: 0.1959 (0.2025)  loss_box_reg: 0.1953 (0.1932)  loss_objectness: 0.0442 (0.0448)  loss_rpn_box_reg: 0.1261 (0.1270)  time: 1.9669  data: 0.0949  max mem: 11736
# Epoch: [0] Total time: 0:07:26 (2.1343 s / it)
# creating index...
# index created!
# Test:  [0/4]  eta: 0:00:27  model_time: 0.6427 (0.6427)  evaluator_time: 2.4538 (2.4538)  time: 6.8885  data: 3.5856  max mem: 11736
# Test:  [3/4]  eta: 0:00:03  model_time: 0.6354 (0.5061)  evaluator_time: 2.4538 (2.2729)  time: 3.8316  data: 0.9377  max mem: 11736
# Test: Total time: 0:00:15 (3.8484 s / it)
# Averaged stats: model_time: 0.6354 (0.5061)  evaluator_time: 2.4538 (2.2729)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.491
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.910
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.481
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.057
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.485
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.548
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.017
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.151
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.554
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.100
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.550
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.598
# Epoch: [1]  [  0/209]  eta: 0:30:20  lr: 0.005000  loss: 0.5303 (0.5303)  loss_classifier: 0.2004 (0.2004)  loss_box_reg: 0.1784 (0.1784)  loss_objectness: 0.0372 (0.0372)  loss_rpn_box_reg: 0.1144 (0.1144)  time: 8.7123  data: 6.2621  max mem: 11736
# Epoch: [1]  [ 10/209]  eta: 0:09:40  lr: 0.005000  loss: 0.5354 (0.5462)  loss_classifier: 0.2004 (0.2012)  loss_box_reg: 0.1931 (0.1900)  loss_objectness: 0.0356 (0.0365)  loss_rpn_box_reg: 0.1187 (0.1185)  time: 2.9169  data: 0.7338  max mem: 11736
# Epoch: [1]  [ 20/209]  eta: 0:07:54  lr: 0.005000  loss: 0.5617 (0.5675)  loss_classifier: 0.2048 (0.2058)  loss_box_reg: 0.1932 (0.1938)  loss_objectness: 0.0397 (0.0418)  loss_rpn_box_reg: 0.1258 (0.1261)  time: 2.1996  data: 0.1419  max mem: 11736
# Epoch: [1]  [ 30/209]  eta: 0:07:06  lr: 0.005000  loss: 0.5672 (0.5657)  loss_classifier: 0.2027 (0.2023)  loss_box_reg: 0.1917 (0.1920)  loss_objectness: 0.0458 (0.0434)  loss_rpn_box_reg: 0.1318 (0.1281)  time: 2.0857  data: 0.1121  max mem: 11736
# Epoch: [1]  [ 40/209]  eta: 0:06:32  lr: 0.005000  loss: 0.5577 (0.5632)  loss_classifier: 0.1975 (0.2013)  loss_box_reg: 0.1909 (0.1913)  loss_objectness: 0.0421 (0.0425)  loss_rpn_box_reg: 0.1304 (0.1281)  time: 2.1217  data: 0.1200  max mem: 11736
# Epoch: [1]  [ 50/209]  eta: 0:06:01  lr: 0.005000  loss: 0.5565 (0.5614)  loss_classifier: 0.1955 (0.1993)  loss_box_reg: 0.1896 (0.1906)  loss_objectness: 0.0400 (0.0426)  loss_rpn_box_reg: 0.1287 (0.1290)  time: 2.1044  data: 0.1106  max mem: 11736
# Epoch: [1]  [ 60/209]  eta: 0:05:34  lr: 0.005000  loss: 0.5565 (0.5648)  loss_classifier: 0.1963 (0.1999)  loss_box_reg: 0.1871 (0.1915)  loss_objectness: 0.0428 (0.0433)  loss_rpn_box_reg: 0.1296 (0.1300)  time: 2.0971  data: 0.1023  max mem: 11736
# Epoch: [1]  [ 70/209]  eta: 0:05:08  lr: 0.005000  loss: 0.5545 (0.5651)  loss_classifier: 0.1991 (0.1997)  loss_box_reg: 0.1927 (0.1919)  loss_objectness: 0.0434 (0.0434)  loss_rpn_box_reg: 0.1310 (0.1302)  time: 2.0901  data: 0.1039  max mem: 11736
# Epoch: [1]  [ 80/209]  eta: 0:04:43  lr: 0.005000  loss: 0.5527 (0.5667)  loss_classifier: 0.1957 (0.2002)  loss_box_reg: 0.1924 (0.1923)  loss_objectness: 0.0431 (0.0441)  loss_rpn_box_reg: 0.1267 (0.1301)  time: 2.0493  data: 0.1033  max mem: 11736
# Epoch: [1]  [ 90/209]  eta: 0:04:21  lr: 0.005000  loss: 0.5527 (0.5661)  loss_classifier: 0.1991 (0.2004)  loss_box_reg: 0.1855 (0.1921)  loss_objectness: 0.0425 (0.0438)  loss_rpn_box_reg: 0.1237 (0.1297)  time: 2.0980  data: 0.1091  max mem: 11736
# Epoch: [1]  [100/209]  eta: 0:03:57  lr: 0.005000  loss: 0.5648 (0.5670)  loss_classifier: 0.2029 (0.2010)  loss_box_reg: 0.1950 (0.1927)  loss_objectness: 0.0425 (0.0441)  loss_rpn_box_reg: 0.1277 (0.1293)  time: 2.1000  data: 0.1095  max mem: 11736
# Epoch: [1]  [110/209]  eta: 0:03:34  lr: 0.005000  loss: 0.5550 (0.5640)  loss_classifier: 0.1993 (0.2004)  loss_box_reg: 0.1886 (0.1919)  loss_objectness: 0.0387 (0.0435)  loss_rpn_box_reg: 0.1230 (0.1283)  time: 2.0411  data: 0.0998  max mem: 11736
# Epoch: [1]  [120/209]  eta: 0:03:12  lr: 0.005000  loss: 0.5314 (0.5627)  loss_classifier: 0.1915 (0.1996)  loss_box_reg: 0.1858 (0.1915)  loss_objectness: 0.0339 (0.0434)  loss_rpn_box_reg: 0.1202 (0.1282)  time: 2.0926  data: 0.1093  max mem: 11736
# Epoch: [1]  [130/209]  eta: 0:02:50  lr: 0.005000  loss: 0.5405 (0.5613)  loss_classifier: 0.1915 (0.1993)  loss_box_reg: 0.1835 (0.1909)  loss_objectness: 0.0415 (0.0432)  loss_rpn_box_reg: 0.1263 (0.1279)  time: 2.1133  data: 0.1100  max mem: 11736
# Epoch: [1]  [140/209]  eta: 0:02:28  lr: 0.005000  loss: 0.5405 (0.5599)  loss_classifier: 0.1904 (0.1988)  loss_box_reg: 0.1835 (0.1904)  loss_objectness: 0.0426 (0.0431)  loss_rpn_box_reg: 0.1259 (0.1276)  time: 2.0794  data: 0.1044  max mem: 11736
# Epoch: [1]  [150/209]  eta: 0:02:06  lr: 0.005000  loss: 0.5637 (0.5609)  loss_classifier: 0.2012 (0.1996)  loss_box_reg: 0.1906 (0.1905)  loss_objectness: 0.0407 (0.0430)  loss_rpn_box_reg: 0.1264 (0.1278)  time: 2.0975  data: 0.1140  max mem: 11736
# Epoch: [1]  [160/209]  eta: 0:01:45  lr: 0.005000  loss: 0.5662 (0.5608)  loss_classifier: 0.2065 (0.1998)  loss_box_reg: 0.1941 (0.1908)  loss_objectness: 0.0378 (0.0427)  loss_rpn_box_reg: 0.1250 (0.1275)  time: 2.0752  data: 0.1139  max mem: 11736
# Epoch: [1]  [170/209]  eta: 0:01:23  lr: 0.005000  loss: 0.5591 (0.5598)  loss_classifier: 0.2040 (0.1997)  loss_box_reg: 0.1944 (0.1906)  loss_objectness: 0.0364 (0.0425)  loss_rpn_box_reg: 0.1209 (0.1270)  time: 2.0621  data: 0.1134  max mem: 11736
# Epoch: [1]  [180/209]  eta: 0:01:02  lr: 0.005000  loss: 0.5614 (0.5605)  loss_classifier: 0.2018 (0.1998)  loss_box_reg: 0.1962 (0.1911)  loss_objectness: 0.0385 (0.0426)  loss_rpn_box_reg: 0.1193 (0.1271)  time: 2.1017  data: 0.1135  max mem: 11736
# Epoch: [1]  [190/209]  eta: 0:00:40  lr: 0.005000  loss: 0.5681 (0.5610)  loss_classifier: 0.1997 (0.1999)  loss_box_reg: 0.1936 (0.1911)  loss_objectness: 0.0439 (0.0429)  loss_rpn_box_reg: 0.1254 (0.1272)  time: 2.1024  data: 0.1044  max mem: 11736
# Epoch: [1]  [200/209]  eta: 0:00:19  lr: 0.005000  loss: 0.5682 (0.5613)  loss_classifier: 0.1995 (0.2000)  loss_box_reg: 0.1936 (0.1913)  loss_objectness: 0.0446 (0.0429)  loss_rpn_box_reg: 0.1291 (0.1272)  time: 2.0777  data: 0.1022  max mem: 11736
# Epoch: [1]  [208/209]  eta: 0:00:02  lr: 0.005000  loss: 0.5745 (0.5618)  loss_classifier: 0.2005 (0.2003)  loss_box_reg: 0.1956 (0.1916)  loss_objectness: 0.0432 (0.0428)  loss_rpn_box_reg: 0.1291 (0.1271)  time: 1.9217  data: 0.0900  max mem: 11736
# Epoch: [1] Total time: 0:07:22 (2.1161 s / it)
# creating index...
# index created!
# Test:  [0/4]  eta: 0:00:29  model_time: 0.6482 (0.6482)  evaluator_time: 2.5801 (2.5801)  time: 7.4206  data: 3.9796  max mem: 11736
# Test:  [3/4]  eta: 0:00:03  model_time: 0.6314 (0.5077)  evaluator_time: 2.5801 (2.2401)  time: 3.9011  data: 1.0374  max mem: 11736
# Test: Total time: 0:00:15 (3.9190 s / it)
# Averaged stats: model_time: 0.6314 (0.5077)  evaluator_time: 2.5801 (2.2401)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.479
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.902
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.450
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.082
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.479
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.499
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.016
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.144
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.544
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.126
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.549
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.538
# Epoch: [2]  [  0/209]  eta: 0:29:04  lr: 0.005000  loss: 0.5004 (0.5004)  loss_classifier: 0.1812 (0.1812)  loss_box_reg: 0.1683 (0.1683)  loss_objectness: 0.0315 (0.0315)  loss_rpn_box_reg: 0.1193 (0.1193)  time: 8.3482  data: 5.7837  max mem: 11736
# Epoch: [2]  [ 10/209]  eta: 0:09:10  lr: 0.005000  loss: 0.5395 (0.5426)  loss_classifier: 0.1894 (0.1922)  loss_box_reg: 0.1871 (0.1872)  loss_objectness: 0.0370 (0.0388)  loss_rpn_box_reg: 0.1218 (0.1244)  time: 2.7656  data: 0.6489  max mem: 11736
# Epoch: [2]  [ 20/209]  eta: 0:07:47  lr: 0.005000  loss: 0.5467 (0.5493)  loss_classifier: 0.1965 (0.1961)  loss_box_reg: 0.1871 (0.1885)  loss_objectness: 0.0404 (0.0390)  loss_rpn_box_reg: 0.1256 (0.1257)  time: 2.1799  data: 0.1206  max mem: 11736
# Epoch: [2]  [ 30/209]  eta: 0:07:01  lr: 0.005000  loss: 0.5634 (0.5504)  loss_classifier: 0.2004 (0.1981)  loss_box_reg: 0.1870 (0.1876)  loss_objectness: 0.0361 (0.0385)  loss_rpn_box_reg: 0.1262 (0.1262)  time: 2.1249  data: 0.1071  max mem: 11736
# Epoch: [2]  [ 40/209]  eta: 0:06:25  lr: 0.005000  loss: 0.5444 (0.5497)  loss_classifier: 0.1934 (0.1979)  loss_box_reg: 0.1877 (0.1876)  loss_objectness: 0.0372 (0.0384)  loss_rpn_box_reg: 0.1260 (0.1258)  time: 2.0827  data: 0.1046  max mem: 11736
# Epoch: [2]  [ 50/209]  eta: 0:05:57  lr: 0.005000  loss: 0.5273 (0.5449)  loss_classifier: 0.1924 (0.1964)  loss_box_reg: 0.1807 (0.1868)  loss_objectness: 0.0363 (0.0378)  loss_rpn_box_reg: 0.1205 (0.1239)  time: 2.0949  data: 0.1053  max mem: 11736
# Epoch: [2]  [ 60/209]  eta: 0:05:31  lr: 0.005000  loss: 0.5381 (0.5450)  loss_classifier: 0.1916 (0.1960)  loss_box_reg: 0.1837 (0.1874)  loss_objectness: 0.0353 (0.0377)  loss_rpn_box_reg: 0.1223 (0.1240)  time: 2.0989  data: 0.1069  max mem: 11736
# Epoch: [2]  [ 70/209]  eta: 0:05:06  lr: 0.005000  loss: 0.5513 (0.5469)  loss_classifier: 0.1965 (0.1965)  loss_box_reg: 0.1934 (0.1880)  loss_objectness: 0.0366 (0.0382)  loss_rpn_box_reg: 0.1246 (0.1242)  time: 2.0753  data: 0.1034  max mem: 11736
# Epoch: [2]  [ 80/209]  eta: 0:04:43  lr: 0.005000  loss: 0.5429 (0.5464)  loss_classifier: 0.1986 (0.1968)  loss_box_reg: 0.1904 (0.1876)  loss_objectness: 0.0366 (0.0378)  loss_rpn_box_reg: 0.1246 (0.1242)  time: 2.1102  data: 0.1143  max mem: 11736
# Epoch: [2]  [ 90/209]  eta: 0:04:19  lr: 0.005000  loss: 0.5382 (0.5449)  loss_classifier: 0.1964 (0.1963)  loss_box_reg: 0.1830 (0.1872)  loss_objectness: 0.0365 (0.0378)  loss_rpn_box_reg: 0.1221 (0.1235)  time: 2.1022  data: 0.1151  max mem: 11736
# Epoch: [2]  [100/209]  eta: 0:03:56  lr: 0.005000  loss: 0.5406 (0.5466)  loss_classifier: 0.1964 (0.1968)  loss_box_reg: 0.1870 (0.1879)  loss_objectness: 0.0370 (0.0380)  loss_rpn_box_reg: 0.1215 (0.1240)  time: 2.0820  data: 0.1063  max mem: 11736
# Epoch: [2]  [110/209]  eta: 0:03:34  lr: 0.005000  loss: 0.5500 (0.5471)  loss_classifier: 0.1992 (0.1973)  loss_box_reg: 0.1942 (0.1883)  loss_objectness: 0.0358 (0.0377)  loss_rpn_box_reg: 0.1259 (0.1239)  time: 2.1121  data: 0.1063  max mem: 11736
# Epoch: [2]  [120/209]  eta: 0:03:11  lr: 0.005000  loss: 0.5500 (0.5483)  loss_classifier: 0.1979 (0.1976)  loss_box_reg: 0.1920 (0.1883)  loss_objectness: 0.0388 (0.0384)  loss_rpn_box_reg: 0.1239 (0.1241)  time: 2.0779  data: 0.1020  max mem: 11736
# Epoch: [2]  [130/209]  eta: 0:02:49  lr: 0.005000  loss: 0.5615 (0.5489)  loss_classifier: 0.2005 (0.1979)  loss_box_reg: 0.1918 (0.1884)  loss_objectness: 0.0430 (0.0386)  loss_rpn_box_reg: 0.1220 (0.1240)  time: 2.0506  data: 0.0993  max mem: 11736
# Epoch: [2]  [140/209]  eta: 0:02:28  lr: 0.005000  loss: 0.5535 (0.5492)  loss_classifier: 0.2005 (0.1978)  loss_box_reg: 0.1885 (0.1884)  loss_objectness: 0.0427 (0.0388)  loss_rpn_box_reg: 0.1227 (0.1241)  time: 2.0823  data: 0.0994  max mem: 11736
# Epoch: [2]  [150/209]  eta: 0:02:06  lr: 0.005000  loss: 0.5535 (0.5509)  loss_classifier: 0.1949 (0.1982)  loss_box_reg: 0.1928 (0.1887)  loss_objectness: 0.0434 (0.0393)  loss_rpn_box_reg: 0.1250 (0.1247)  time: 2.0960  data: 0.0996  max mem: 11736
# Epoch: [2]  [160/209]  eta: 0:01:44  lr: 0.005000  loss: 0.5531 (0.5507)  loss_classifier: 0.1917 (0.1977)  loss_box_reg: 0.1832 (0.1883)  loss_objectness: 0.0416 (0.0393)  loss_rpn_box_reg: 0.1292 (0.1253)  time: 2.1092  data: 0.1183  max mem: 11736
# Epoch: [2]  [170/209]  eta: 0:01:23  lr: 0.005000  loss: 0.5466 (0.5499)  loss_classifier: 0.1917 (0.1975)  loss_box_reg: 0.1799 (0.1882)  loss_objectness: 0.0378 (0.0391)  loss_rpn_box_reg: 0.1242 (0.1251)  time: 2.0975  data: 0.1242  max mem: 11736
# Epoch: [2]  [180/209]  eta: 0:01:01  lr: 0.005000  loss: 0.5466 (0.5501)  loss_classifier: 0.2005 (0.1977)  loss_box_reg: 0.1896 (0.1881)  loss_objectness: 0.0354 (0.0391)  loss_rpn_box_reg: 0.1216 (0.1251)  time: 2.0782  data: 0.1134  max mem: 11736
# Epoch: [2]  [190/209]  eta: 0:00:40  lr: 0.005000  loss: 0.5581 (0.5506)  loss_classifier: 0.1980 (0.1977)  loss_box_reg: 0.1907 (0.1883)  loss_objectness: 0.0430 (0.0394)  loss_rpn_box_reg: 0.1265 (0.1252)  time: 2.1111  data: 0.1181  max mem: 11736
# Epoch: [2]  [200/209]  eta: 0:00:19  lr: 0.005000  loss: 0.5526 (0.5501)  loss_classifier: 0.1933 (0.1973)  loss_box_reg: 0.1907 (0.1880)  loss_objectness: 0.0404 (0.0394)  loss_rpn_box_reg: 0.1267 (0.1254)  time: 2.1000  data: 0.1106  max mem: 11736
# Epoch: [2]  [208/209]  eta: 0:00:02  lr: 0.005000  loss: 0.5470 (0.5505)  loss_classifier: 0.1935 (0.1974)  loss_box_reg: 0.1906 (0.1885)  loss_objectness: 0.0380 (0.0394)  loss_rpn_box_reg: 0.1258 (0.1252)  time: 1.9163  data: 0.0953  max mem: 11736
# Epoch: [2] Total time: 0:07:21 (2.1138 s / it)
# creating index...
# index created!
# Test:  [0/4]  eta: 0:00:27  model_time: 0.6456 (0.6456)  evaluator_time: 2.5546 (2.5546)  time: 6.8612  data: 3.4817  max mem: 11736
# Test:  [3/4]  eta: 0:00:03  model_time: 0.6322 (0.5069)  evaluator_time: 2.5546 (2.2802)  time: 3.8078  data: 0.9126  max mem: 11736
# Test: Total time: 0:00:15 (3.8253 s / it)
# Averaged stats: model_time: 0.6322 (0.5069)  evaluator_time: 2.5546 (2.2802)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.503
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.922
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.492
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.082
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.498
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.553
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.017
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.152
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.565
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.116
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.563
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.602
# Epoch: [3]  [  0/209]  eta: 0:24:30  lr: 0.000500  loss: 0.5352 (0.5352)  loss_classifier: 0.2009 (0.2009)  loss_box_reg: 0.1897 (0.1897)  loss_objectness: 0.0351 (0.0351)  loss_rpn_box_reg: 0.1095 (0.1095)  time: 7.0347  data: 4.3911  max mem: 11736
# Epoch: [3]  [ 10/209]  eta: 0:09:29  lr: 0.000500  loss: 0.5398 (0.5321)  loss_classifier: 0.1937 (0.1915)  loss_box_reg: 0.1897 (0.1848)  loss_objectness: 0.0350 (0.0348)  loss_rpn_box_reg: 0.1211 (0.1210)  time: 2.8632  data: 0.6110  max mem: 11736
# Epoch: [3]  [ 20/209]  eta: 0:07:47  lr: 0.000500  loss: 0.5394 (0.5282)  loss_classifier: 0.1920 (0.1900)  loss_box_reg: 0.1831 (0.1836)  loss_objectness: 0.0350 (0.0350)  loss_rpn_box_reg: 0.1179 (0.1196)  time: 2.2481  data: 0.1666  max mem: 11737
# Epoch: [3]  [ 30/209]  eta: 0:06:59  lr: 0.000500  loss: 0.5147 (0.5230)  loss_classifier: 0.1838 (0.1870)  loss_box_reg: 0.1792 (0.1815)  loss_objectness: 0.0334 (0.0341)  loss_rpn_box_reg: 0.1168 (0.1204)  time: 2.0539  data: 0.1018  max mem: 11737
# Epoch: [3]  [ 40/209]  eta: 0:06:27  lr: 0.000500  loss: 0.5147 (0.5241)  loss_classifier: 0.1819 (0.1878)  loss_box_reg: 0.1766 (0.1808)  loss_objectness: 0.0334 (0.0344)  loss_rpn_box_reg: 0.1178 (0.1211)  time: 2.1016  data: 0.1181  max mem: 11737
# Epoch: [3]  [ 50/209]  eta: 0:05:57  lr: 0.000500  loss: 0.5164 (0.5239)  loss_classifier: 0.1819 (0.1867)  loss_box_reg: 0.1780 (0.1804)  loss_objectness: 0.0368 (0.0350)  loss_rpn_box_reg: 0.1196 (0.1219)  time: 2.0972  data: 0.1175  max mem: 11737
# Epoch: [3]  [ 60/209]  eta: 0:05:30  lr: 0.000500  loss: 0.5230 (0.5272)  loss_classifier: 0.1810 (0.1878)  loss_box_reg: 0.1795 (0.1812)  loss_objectness: 0.0384 (0.0360)  loss_rpn_box_reg: 0.1239 (0.1223)  time: 2.0683  data: 0.1043  max mem: 11737
# Epoch: [3]  [ 70/209]  eta: 0:05:06  lr: 0.000500  loss: 0.5462 (0.5287)  loss_classifier: 0.1926 (0.1883)  loss_box_reg: 0.1876 (0.1821)  loss_objectness: 0.0361 (0.0359)  loss_rpn_box_reg: 0.1170 (0.1223)  time: 2.1064  data: 0.1126  max mem: 11737
# Epoch: [3]  [ 80/209]  eta: 0:04:42  lr: 0.000500  loss: 0.5469 (0.5301)  loss_classifier: 0.1935 (0.1895)  loss_box_reg: 0.1912 (0.1825)  loss_objectness: 0.0344 (0.0357)  loss_rpn_box_reg: 0.1209 (0.1223)  time: 2.0866  data: 0.1099  max mem: 11737
# Epoch: [3]  [ 90/209]  eta: 0:04:19  lr: 0.000500  loss: 0.5379 (0.5306)  loss_classifier: 0.1938 (0.1897)  loss_box_reg: 0.1799 (0.1825)  loss_objectness: 0.0342 (0.0359)  loss_rpn_box_reg: 0.1220 (0.1225)  time: 2.0893  data: 0.1195  max mem: 11737
# Epoch: [3]  [100/209]  eta: 0:03:56  lr: 0.000500  loss: 0.5150 (0.5304)  loss_classifier: 0.1894 (0.1897)  loss_box_reg: 0.1783 (0.1823)  loss_objectness: 0.0315 (0.0358)  loss_rpn_box_reg: 0.1220 (0.1226)  time: 2.1206  data: 0.1247  max mem: 11737
# Epoch: [3]  [110/209]  eta: 0:03:34  lr: 0.000500  loss: 0.5233 (0.5306)  loss_classifier: 0.1911 (0.1898)  loss_box_reg: 0.1832 (0.1826)  loss_objectness: 0.0314 (0.0357)  loss_rpn_box_reg: 0.1232 (0.1225)  time: 2.0777  data: 0.1057  max mem: 11737
# Epoch: [3]  [120/209]  eta: 0:03:12  lr: 0.000500  loss: 0.5277 (0.5305)  loss_classifier: 0.1917 (0.1901)  loss_box_reg: 0.1827 (0.1826)  loss_objectness: 0.0314 (0.0355)  loss_rpn_box_reg: 0.1204 (0.1223)  time: 2.0785  data: 0.1107  max mem: 11737
# Epoch: [3]  [130/209]  eta: 0:02:50  lr: 0.000500  loss: 0.5200 (0.5290)  loss_classifier: 0.1872 (0.1897)  loss_box_reg: 0.1813 (0.1822)  loss_objectness: 0.0305 (0.0352)  loss_rpn_box_reg: 0.1156 (0.1219)  time: 2.1046  data: 0.1178  max mem: 11737
# Epoch: [3]  [140/209]  eta: 0:02:28  lr: 0.000500  loss: 0.5149 (0.5272)  loss_classifier: 0.1856 (0.1892)  loss_box_reg: 0.1801 (0.1818)  loss_objectness: 0.0298 (0.0349)  loss_rpn_box_reg: 0.1132 (0.1213)  time: 2.0682  data: 0.1090  max mem: 11737
# Epoch: [3]  [150/209]  eta: 0:02:06  lr: 0.000500  loss: 0.5246 (0.5269)  loss_classifier: 0.1868 (0.1893)  loss_box_reg: 0.1813 (0.1817)  loss_objectness: 0.0332 (0.0350)  loss_rpn_box_reg: 0.1147 (0.1210)  time: 2.0878  data: 0.1136  max mem: 11737
# Epoch: [3]  [160/209]  eta: 0:01:44  lr: 0.000500  loss: 0.5306 (0.5266)  loss_classifier: 0.1862 (0.1891)  loss_box_reg: 0.1781 (0.1815)  loss_objectness: 0.0357 (0.0352)  loss_rpn_box_reg: 0.1147 (0.1208)  time: 2.1038  data: 0.1139  max mem: 11737
# Epoch: [3]  [170/209]  eta: 0:01:22  lr: 0.000500  loss: 0.5331 (0.5262)  loss_classifier: 0.1847 (0.1891)  loss_box_reg: 0.1765 (0.1814)  loss_objectness: 0.0382 (0.0352)  loss_rpn_box_reg: 0.1176 (0.1206)  time: 1.9997  data: 0.0946  max mem: 11737
# Epoch: [3]  [180/209]  eta: 0:01:02  lr: 0.000500  loss: 0.5299 (0.5256)  loss_classifier: 0.1883 (0.1890)  loss_box_reg: 0.1831 (0.1812)  loss_objectness: 0.0326 (0.0350)  loss_rpn_box_reg: 0.1180 (0.1204)  time: 2.4234  data: 0.3690  max mem: 11737
# Epoch: [3]  [190/209]  eta: 0:00:41  lr: 0.000500  loss: 0.5237 (0.5254)  loss_classifier: 0.1832 (0.1890)  loss_box_reg: 0.1828 (0.1813)  loss_objectness: 0.0303 (0.0349)  loss_rpn_box_reg: 0.1164 (0.1202)  time: 2.4845  data: 0.3766  max mem: 11737
# Epoch: [3]  [200/209]  eta: 0:00:19  lr: 0.000500  loss: 0.5129 (0.5254)  loss_classifier: 0.1894 (0.1892)  loss_box_reg: 0.1826 (0.1813)  loss_objectness: 0.0324 (0.0349)  loss_rpn_box_reg: 0.1156 (0.1200)  time: 2.0673  data: 0.1079  max mem: 11737
# Epoch: [3]  [208/209]  eta: 0:00:02  lr: 0.000500  loss: 0.5129 (0.5250)  loss_classifier: 0.1893 (0.1891)  loss_box_reg: 0.1718 (0.1810)  loss_objectness: 0.0328 (0.0349)  loss_rpn_box_reg: 0.1146 (0.1200)  time: 1.9189  data: 0.0961  max mem: 11737
# Epoch: [3] Total time: 0:07:27 (2.1431 s / it)
# creating index...
# index created!
# Test:  [0/4]  eta: 0:00:28  model_time: 0.6456 (0.6456)  evaluator_time: 2.3751 (2.3751)  time: 7.2183  data: 4.0382  max mem: 11737
# Test:  [3/4]  eta: 0:00:03  model_time: 0.6313 (0.5061)  evaluator_time: 2.3751 (2.1561)  time: 3.8032  data: 1.0396  max mem: 11737
# Test: Total time: 0:00:15 (3.8225 s / it)
# Averaged stats: model_time: 0.6313 (0.5061)  evaluator_time: 2.3751 (2.1561)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.508
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.915
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.509
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.064
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.502
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.558
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.017
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.154
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.567
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.121
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.565
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.607

# %% [markdown]
# ## Pseudo Labeling Round #2

# %%
pseudo_train_df = get_pseudo_labels(test_data_loader)
train_df = get_train_df()
train_df = pd.concat([train_df, pseudo_train_df]).reset_index(drop=True)

# There are some huge bounding boxes in the training dataset. Let's get rid of them
train_df = train_df[train_df['height'] * train_df['width'] < 100000].reset_index(drop=True)
train_df['area'] = train_df['width'] * train_df['height']
train_df
# Out:
#          image_id  x_min  y_min  width  height     area
# 0       b6ab77fd7  834.0  222.0   56.0    36.0   2016.0
# 1       b6ab77fd7  226.0  548.0  130.0    58.0   7540.0
# 2       b6ab77fd7  377.0  504.0   74.0   160.0  11840.0
# 3       b6ab77fd7  834.0   95.0  109.0   107.0  11663.0
# 4       b6ab77fd7   26.0  144.0  124.0   117.0  14508.0
# ...           ...    ...    ...    ...     ...      ...
# 148010  53f253011  725.0  369.0  149.0   124.0  18476.0
# 148011  53f253011  298.0  610.0  124.0    96.0  11904.0
# 148012  53f253011  414.0  267.0  109.0    96.0  10464.0
# 148013  53f253011  527.0  399.0   73.0    68.0   4964.0
# 148014  53f253011  140.0  619.0   87.0   124.0  10788.0
#
# [148015 rows x 6 columns]

# %%
# train_df = train_df[:2000]

# %%
train(train_df)
# Out:
# Epoch: [0]  [  0/209]  eta: 0:30:44  lr: 0.000029  loss: 0.5378 (0.5378)  loss_classifier: 0.1778 (0.1778)  loss_box_reg: 0.1748 (0.1748)  loss_objectness: 0.0415 (0.0415)  loss_rpn_box_reg: 0.1437 (0.1437)  time: 8.8241  data: 6.2068  max mem: 11737
# Epoch: [0]  [ 10/209]  eta: 0:09:19  lr: 0.000269  loss: 0.5479 (0.5373)  loss_classifier: 0.1871 (0.1899)  loss_box_reg: 0.1871 (0.1837)  loss_objectness: 0.0395 (0.0393)  loss_rpn_box_reg: 0.1248 (0.1244)  time: 2.8099  data: 0.6635  max mem: 11737
# Epoch: [0]  [ 20/209]  eta: 0:07:51  lr: 0.000509  loss: 0.5373 (0.5319)  loss_classifier: 0.1871 (0.1910)  loss_box_reg: 0.1862 (0.1821)  loss_objectness: 0.0384 (0.0380)  loss_rpn_box_reg: 0.1207 (0.1208)  time: 2.1798  data: 0.1208  max mem: 11737
# Epoch: [0]  [ 30/209]  eta: 0:07:00  lr: 0.000749  loss: 0.5151 (0.5273)  loss_classifier: 0.1840 (0.1887)  loss_box_reg: 0.1769 (0.1808)  loss_objectness: 0.0330 (0.0364)  loss_rpn_box_reg: 0.1173 (0.1213)  time: 2.0969  data: 0.1159  max mem: 11737
# Epoch: [0]  [ 40/209]  eta: 0:06:24  lr: 0.000990  loss: 0.5171 (0.5277)  loss_classifier: 0.1892 (0.1898)  loss_box_reg: 0.1761 (0.1810)  loss_objectness: 0.0329 (0.0360)  loss_rpn_box_reg: 0.1171 (0.1209)  time: 2.0485  data: 0.0995  max mem: 11737
# Epoch: [0]  [ 50/209]  eta: 0:05:58  lr: 0.001230  loss: 0.5328 (0.5285)  loss_classifier: 0.1943 (0.1906)  loss_box_reg: 0.1824 (0.1810)  loss_objectness: 0.0334 (0.0358)  loss_rpn_box_reg: 0.1187 (0.1211)  time: 2.1019  data: 0.1026  max mem: 11737
# Epoch: [0]  [ 60/209]  eta: 0:05:30  lr: 0.001470  loss: 0.5328 (0.5297)  loss_classifier: 0.1920 (0.1914)  loss_box_reg: 0.1824 (0.1817)  loss_objectness: 0.0363 (0.0355)  loss_rpn_box_reg: 0.1220 (0.1210)  time: 2.0906  data: 0.1073  max mem: 11737
# Epoch: [0]  [ 70/209]  eta: 0:05:06  lr: 0.001710  loss: 0.5110 (0.5286)  loss_classifier: 0.1920 (0.1911)  loss_box_reg: 0.1807 (0.1814)  loss_objectness: 0.0334 (0.0357)  loss_rpn_box_reg: 0.1140 (0.1204)  time: 2.0773  data: 0.1080  max mem: 11737
# Epoch: [0]  [ 80/209]  eta: 0:04:43  lr: 0.001950  loss: 0.5110 (0.5283)  loss_classifier: 0.1851 (0.1907)  loss_box_reg: 0.1802 (0.1812)  loss_objectness: 0.0321 (0.0353)  loss_rpn_box_reg: 0.1186 (0.1211)  time: 2.1435  data: 0.1102  max mem: 11737
# Epoch: [0]  [ 90/209]  eta: 0:04:19  lr: 0.002190  loss: 0.5177 (0.5268)  loss_classifier: 0.1842 (0.1901)  loss_box_reg: 0.1773 (0.1807)  loss_objectness: 0.0314 (0.0354)  loss_rpn_box_reg: 0.1182 (0.1206)  time: 2.1158  data: 0.1102  max mem: 11737
# Epoch: [0]  [100/209]  eta: 0:03:57  lr: 0.002430  loss: 0.5286 (0.5291)  loss_classifier: 0.1938 (0.1908)  loss_box_reg: 0.1854 (0.1818)  loss_objectness: 0.0351 (0.0356)  loss_rpn_box_reg: 0.1182 (0.1210)  time: 2.1148  data: 0.1124  max mem: 11737
# Epoch: [0]  [110/209]  eta: 0:03:35  lr: 0.002671  loss: 0.5357 (0.5286)  loss_classifier: 0.1946 (0.1906)  loss_box_reg: 0.1871 (0.1817)  loss_objectness: 0.0355 (0.0356)  loss_rpn_box_reg: 0.1204 (0.1207)  time: 2.1419  data: 0.1113  max mem: 11737
# Epoch: [0]  [120/209]  eta: 0:03:13  lr: 0.002911  loss: 0.5222 (0.5275)  loss_classifier: 0.1911 (0.1903)  loss_box_reg: 0.1789 (0.1814)  loss_objectness: 0.0328 (0.0353)  loss_rpn_box_reg: 0.1188 (0.1205)  time: 2.1035  data: 0.1036  max mem: 11737
# Epoch: [0]  [130/209]  eta: 0:02:50  lr: 0.003151  loss: 0.5077 (0.5266)  loss_classifier: 0.1861 (0.1904)  loss_box_reg: 0.1770 (0.1810)  loss_objectness: 0.0291 (0.0349)  loss_rpn_box_reg: 0.1191 (0.1203)  time: 2.0967  data: 0.1046  max mem: 11737
# Epoch: [0]  [140/209]  eta: 0:02:29  lr: 0.003391  loss: 0.5077 (0.5261)  loss_classifier: 0.1864 (0.1903)  loss_box_reg: 0.1794 (0.1811)  loss_objectness: 0.0308 (0.0348)  loss_rpn_box_reg: 0.1181 (0.1200)  time: 2.1183  data: 0.1158  max mem: 11737
# Epoch: [0]  [150/209]  eta: 0:02:07  lr: 0.003631  loss: 0.5196 (0.5260)  loss_classifier: 0.1874 (0.1903)  loss_box_reg: 0.1793 (0.1810)  loss_objectness: 0.0350 (0.0349)  loss_rpn_box_reg: 0.1147 (0.1198)  time: 2.0874  data: 0.1151  max mem: 11737
# Epoch: [0]  [160/209]  eta: 0:01:45  lr: 0.003871  loss: 0.5231 (0.5269)  loss_classifier: 0.1878 (0.1906)  loss_box_reg: 0.1801 (0.1813)  loss_objectness: 0.0338 (0.0348)  loss_rpn_box_reg: 0.1188 (0.1202)  time: 2.1037  data: 0.1044  max mem: 11737
# Epoch: [0]  [170/209]  eta: 0:01:23  lr: 0.004111  loss: 0.5230 (0.5262)  loss_classifier: 0.1904 (0.1903)  loss_box_reg: 0.1794 (0.1810)  loss_objectness: 0.0322 (0.0347)  loss_rpn_box_reg: 0.1203 (0.1202)  time: 2.1240  data: 0.1117  max mem: 11737
# Epoch: [0]  [180/209]  eta: 0:01:02  lr: 0.004352  loss: 0.5272 (0.5269)  loss_classifier: 0.1938 (0.1907)  loss_box_reg: 0.1788 (0.1814)  loss_objectness: 0.0332 (0.0347)  loss_rpn_box_reg: 0.1203 (0.1202)  time: 2.0672  data: 0.1108  max mem: 11737
# Epoch: [0]  [190/209]  eta: 0:00:40  lr: 0.004592  loss: 0.5392 (0.5278)  loss_classifier: 0.1949 (0.1909)  loss_box_reg: 0.1873 (0.1818)  loss_objectness: 0.0345 (0.0347)  loss_rpn_box_reg: 0.1211 (0.1204)  time: 2.1071  data: 0.1187  max mem: 11737
# Epoch: [0]  [200/209]  eta: 0:00:19  lr: 0.004832  loss: 0.5392 (0.5285)  loss_classifier: 0.1981 (0.1914)  loss_box_reg: 0.1900 (0.1821)  loss_objectness: 0.0308 (0.0346)  loss_rpn_box_reg: 0.1211 (0.1205)  time: 2.1170  data: 0.1212  max mem: 11737
# Epoch: [0]  [208/209]  eta: 0:00:02  lr: 0.005000  loss: 0.5418 (0.5294)  loss_classifier: 0.2024 (0.1918)  loss_box_reg: 0.1881 (0.1824)  loss_objectness: 0.0306 (0.0346)  loss_rpn_box_reg: 0.1211 (0.1206)  time: 1.9079  data: 0.0940  max mem: 11737
# Epoch: [0] Total time: 0:07:24 (2.1247 s / it)
# creating index...
# index created!
# Test:  [0/4]  eta: 0:00:30  model_time: 0.6546 (0.6546)  evaluator_time: 2.9880 (2.9880)  time: 7.5135  data: 3.7064  max mem: 11737
# Test:  [3/4]  eta: 0:00:03  model_time: 0.6322 (0.5103)  evaluator_time: 2.7919 (2.2566)  time: 3.8401  data: 0.9685  max mem: 11737
# Test: Total time: 0:00:15 (3.8580 s / it)
# Averaged stats: model_time: 0.6322 (0.5103)  evaluator_time: 2.7919 (2.2566)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.513
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.922
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.508
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.113
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.502
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.579
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.016
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.148
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.572
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.150
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.563
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.631
# Epoch: [1]  [  0/209]  eta: 0:28:30  lr: 0.005000  loss: 0.6113 (0.6113)  loss_classifier: 0.2315 (0.2315)  loss_box_reg: 0.2129 (0.2129)  loss_objectness: 0.0343 (0.0343)  loss_rpn_box_reg: 0.1326 (0.1326)  time: 8.1852  data: 5.7832  max mem: 11737
# Epoch: [1]  [ 10/209]  eta: 0:09:24  lr: 0.005000  loss: 0.5328 (0.5382)  loss_classifier: 0.1945 (0.1953)  loss_box_reg: 0.1853 (0.1867)  loss_objectness: 0.0316 (0.0325)  loss_rpn_box_reg: 0.1267 (0.1237)  time: 2.8388  data: 0.6656  max mem: 11737
# Epoch: [1]  [ 20/209]  eta: 0:07:45  lr: 0.005000  loss: 0.5320 (0.5437)  loss_classifier: 0.1960 (0.1987)  loss_box_reg: 0.1846 (0.1884)  loss_objectness: 0.0316 (0.0328)  loss_rpn_box_reg: 0.1225 (0.1238)  time: 2.1791  data: 0.1309  max mem: 11737
# Epoch: [1]  [ 30/209]  eta: 0:07:03  lr: 0.005000  loss: 0.5297 (0.5333)  loss_classifier: 0.1919 (0.1939)  loss_box_reg: 0.1810 (0.1839)  loss_objectness: 0.0351 (0.0335)  loss_rpn_box_reg: 0.1226 (0.1220)  time: 2.1087  data: 0.1053  max mem: 11737
# Epoch: [1]  [ 40/209]  eta: 0:06:28  lr: 0.005000  loss: 0.5209 (0.5275)  loss_classifier: 0.1864 (0.1906)  loss_box_reg: 0.1716 (0.1814)  loss_objectness: 0.0351 (0.0337)  loss_rpn_box_reg: 0.1211 (0.1218)  time: 2.1213  data: 0.1045  max mem: 11737
# Epoch: [1]  [ 50/209]  eta: 0:05:57  lr: 0.005000  loss: 0.5304 (0.5268)  loss_classifier: 0.1875 (0.1901)  loss_box_reg: 0.1748 (0.1815)  loss_objectness: 0.0336 (0.0332)  loss_rpn_box_reg: 0.1197 (0.1219)  time: 2.0690  data: 0.1033  max mem: 11737
# Epoch: [1]  [ 60/209]  eta: 0:05:32  lr: 0.005000  loss: 0.5067 (0.5255)  loss_classifier: 0.1867 (0.1896)  loss_box_reg: 0.1794 (0.1812)  loss_objectness: 0.0325 (0.0336)  loss_rpn_box_reg: 0.1182 (0.1210)  time: 2.0891  data: 0.1030  max mem: 11737
# Epoch: [1]  [ 70/209]  eta: 0:05:07  lr: 0.005000  loss: 0.5157 (0.5255)  loss_classifier: 0.1881 (0.1900)  loss_box_reg: 0.1794 (0.1811)  loss_objectness: 0.0345 (0.0339)  loss_rpn_box_reg: 0.1172 (0.1205)  time: 2.1052  data: 0.1027  max mem: 11737
# Epoch: [1]  [ 80/209]  eta: 0:04:42  lr: 0.005000  loss: 0.5295 (0.5262)  loss_classifier: 0.1923 (0.1902)  loss_box_reg: 0.1808 (0.1807)  loss_objectness: 0.0350 (0.0343)  loss_rpn_box_reg: 0.1180 (0.1210)  time: 2.0856  data: 0.1013  max mem: 11737
# Epoch: [1]  [ 90/209]  eta: 0:04:19  lr: 0.005000  loss: 0.5294 (0.5257)  loss_classifier: 0.1929 (0.1908)  loss_box_reg: 0.1770 (0.1802)  loss_objectness: 0.0328 (0.0340)  loss_rpn_box_reg: 0.1209 (0.1208)  time: 2.0738  data: 0.1081  max mem: 11737
# Epoch: [1]  [100/209]  eta: 0:03:56  lr: 0.005000  loss: 0.5105 (0.5251)  loss_classifier: 0.1929 (0.1911)  loss_box_reg: 0.1758 (0.1802)  loss_objectness: 0.0287 (0.0337)  loss_rpn_box_reg: 0.1140 (0.1201)  time: 2.0673  data: 0.1063  max mem: 11737
# Epoch: [1]  [110/209]  eta: 0:03:33  lr: 0.005000  loss: 0.5286 (0.5257)  loss_classifier: 0.1920 (0.1913)  loss_box_reg: 0.1799 (0.1806)  loss_objectness: 0.0288 (0.0336)  loss_rpn_box_reg: 0.1158 (0.1203)  time: 2.0363  data: 0.0992  max mem: 11737
# Epoch: [1]  [120/209]  eta: 0:03:11  lr: 0.005000  loss: 0.5361 (0.5276)  loss_classifier: 0.1906 (0.1917)  loss_box_reg: 0.1814 (0.1810)  loss_objectness: 0.0344 (0.0341)  loss_rpn_box_reg: 0.1221 (0.1208)  time: 2.0697  data: 0.1069  max mem: 11737
# Epoch: [1]  [130/209]  eta: 0:02:49  lr: 0.005000  loss: 0.5403 (0.5294)  loss_classifier: 0.1954 (0.1920)  loss_box_reg: 0.1879 (0.1816)  loss_objectness: 0.0368 (0.0343)  loss_rpn_box_reg: 0.1256 (0.1215)  time: 2.0880  data: 0.1058  max mem: 11737
# Epoch: [1]  [140/209]  eta: 0:02:27  lr: 0.005000  loss: 0.5431 (0.5291)  loss_classifier: 0.1933 (0.1915)  loss_box_reg: 0.1852 (0.1815)  loss_objectness: 0.0306 (0.0342)  loss_rpn_box_reg: 0.1255 (0.1219)  time: 2.0566  data: 0.1015  max mem: 11737
# Epoch: [1]  [150/209]  eta: 0:02:06  lr: 0.005000  loss: 0.5256 (0.5291)  loss_classifier: 0.1910 (0.1912)  loss_box_reg: 0.1833 (0.1816)  loss_objectness: 0.0358 (0.0345)  loss_rpn_box_reg: 0.1238 (0.1219)  time: 2.1036  data: 0.1142  max mem: 11737
# Epoch: [1]  [160/209]  eta: 0:01:44  lr: 0.005000  loss: 0.5398 (0.5297)  loss_classifier: 0.1913 (0.1912)  loss_box_reg: 0.1859 (0.1817)  loss_objectness: 0.0370 (0.0346)  loss_rpn_box_reg: 0.1232 (0.1221)  time: 2.1015  data: 0.1139  max mem: 11737
# Epoch: [1]  [170/209]  eta: 0:01:23  lr: 0.005000  loss: 0.5344 (0.5296)  loss_classifier: 0.1911 (0.1910)  loss_box_reg: 0.1856 (0.1816)  loss_objectness: 0.0356 (0.0348)  loss_rpn_box_reg: 0.1232 (0.1222)  time: 2.0628  data: 0.1042  max mem: 11737
# Epoch: [1]  [180/209]  eta: 0:01:01  lr: 0.005000  loss: 0.5157 (0.5280)  loss_classifier: 0.1825 (0.1903)  loss_box_reg: 0.1772 (0.1813)  loss_objectness: 0.0341 (0.0347)  loss_rpn_box_reg: 0.1198 (0.1217)  time: 2.1060  data: 0.1123  max mem: 11737
# Epoch: [1]  [190/209]  eta: 0:00:40  lr: 0.005000  loss: 0.5157 (0.5286)  loss_classifier: 0.1825 (0.1905)  loss_box_reg: 0.1819 (0.1816)  loss_objectness: 0.0335 (0.0348)  loss_rpn_box_reg: 0.1169 (0.1216)  time: 2.1192  data: 0.1136  max mem: 11737
# Epoch: [1]  [200/209]  eta: 0:00:19  lr: 0.005000  loss: 0.5296 (0.5287)  loss_classifier: 0.1943 (0.1908)  loss_box_reg: 0.1819 (0.1816)  loss_objectness: 0.0339 (0.0349)  loss_rpn_box_reg: 0.1200 (0.1215)  time: 2.0687  data: 0.1028  max mem: 11737
# Epoch: [1]  [208/209]  eta: 0:00:02  lr: 0.005000  loss: 0.5261 (0.5289)  loss_classifier: 0.1936 (0.1910)  loss_box_reg: 0.1819 (0.1817)  loss_objectness: 0.0308 (0.0347)  loss_rpn_box_reg: 0.1187 (0.1214)  time: 1.9249  data: 0.0929  max mem: 11737
# Epoch: [1] Total time: 0:07:20 (2.1094 s / it)
# creating index...
# index created!
# Test:  [0/4]  eta: 0:00:30  model_time: 0.6530 (0.6530)  evaluator_time: 2.9847 (2.9847)  time: 7.7024  data: 3.9423  max mem: 11737
# Test:  [3/4]  eta: 0:00:03  model_time: 0.6344 (0.5108)  evaluator_time: 2.6782 (2.1822)  time: 3.7897  data: 1.0027  max mem: 11737
# Test: Total time: 0:00:15 (3.8074 s / it)
# Averaged stats: model_time: 0.6344 (0.5108)  evaluator_time: 2.6782 (2.1822)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.503
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.911
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.488
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.128
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.494
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.565
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.016
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.144
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.565
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.159
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.555
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.627
# Epoch: [2]  [  0/209]  eta: 0:29:18  lr: 0.005000  loss: 0.5728 (0.5728)  loss_classifier: 0.2251 (0.2251)  loss_box_reg: 0.2035 (0.2035)  loss_objectness: 0.0289 (0.0289)  loss_rpn_box_reg: 0.1152 (0.1152)  time: 8.4132  data: 5.9445  max mem: 11737
# Epoch: [2]  [ 10/209]  eta: 0:09:15  lr: 0.005000  loss: 0.5212 (0.5169)  loss_classifier: 0.1905 (0.1897)  loss_box_reg: 0.1817 (0.1808)  loss_objectness: 0.0289 (0.0307)  loss_rpn_box_reg: 0.1164 (0.1158)  time: 2.7908  data: 0.6788  max mem: 11737
# Epoch: [2]  [ 20/209]  eta: 0:07:47  lr: 0.005000  loss: 0.5109 (0.5128)  loss_classifier: 0.1834 (0.1889)  loss_box_reg: 0.1719 (0.1769)  loss_objectness: 0.0280 (0.0304)  loss_rpn_box_reg: 0.1166 (0.1166)  time: 2.1758  data: 0.1420  max mem: 11737
# Epoch: [2]  [ 30/209]  eta: 0:06:59  lr: 0.005000  loss: 0.5134 (0.5161)  loss_classifier: 0.1840 (0.1884)  loss_box_reg: 0.1730 (0.1789)  loss_objectness: 0.0285 (0.0302)  loss_rpn_box_reg: 0.1180 (0.1186)  time: 2.0990  data: 0.1153  max mem: 11737
# Epoch: [2]  [ 40/209]  eta: 0:06:23  lr: 0.005000  loss: 0.5235 (0.5177)  loss_classifier: 0.1840 (0.1879)  loss_box_reg: 0.1797 (0.1786)  loss_objectness: 0.0316 (0.0313)  loss_rpn_box_reg: 0.1231 (0.1198)  time: 2.0552  data: 0.0986  max mem: 11737
# Epoch: [2]  [ 50/209]  eta: 0:05:55  lr: 0.005000  loss: 0.5218 (0.5191)  loss_classifier: 0.1878 (0.1892)  loss_box_reg: 0.1797 (0.1789)  loss_objectness: 0.0318 (0.0313)  loss_rpn_box_reg: 0.1222 (0.1197)  time: 2.0718  data: 0.0995  max mem: 11737
# Epoch: [2]  [ 60/209]  eta: 0:05:29  lr: 0.005000  loss: 0.5218 (0.5189)  loss_classifier: 0.1878 (0.1885)  loss_box_reg: 0.1793 (0.1789)  loss_objectness: 0.0331 (0.0312)  loss_rpn_box_reg: 0.1219 (0.1203)  time: 2.0920  data: 0.1019  max mem: 11737
# Epoch: [2]  [ 70/209]  eta: 0:05:03  lr: 0.005000  loss: 0.5101 (0.5177)  loss_classifier: 0.1816 (0.1876)  loss_box_reg: 0.1770 (0.1786)  loss_objectness: 0.0316 (0.0312)  loss_rpn_box_reg: 0.1206 (0.1203)  time: 2.0569  data: 0.1013  max mem: 11737
# Epoch: [2]  [ 80/209]  eta: 0:04:41  lr: 0.005000  loss: 0.5218 (0.5195)  loss_classifier: 0.1881 (0.1886)  loss_box_reg: 0.1817 (0.1793)  loss_objectness: 0.0310 (0.0313)  loss_rpn_box_reg: 0.1182 (0.1204)  time: 2.0822  data: 0.1074  max mem: 11737
# Epoch: [2]  [ 90/209]  eta: 0:04:17  lr: 0.005000  loss: 0.5120 (0.5198)  loss_classifier: 0.1907 (0.1885)  loss_box_reg: 0.1783 (0.1789)  loss_objectness: 0.0310 (0.0317)  loss_rpn_box_reg: 0.1186 (0.1207)  time: 2.0775  data: 0.1091  max mem: 11737
# Epoch: [2]  [100/209]  eta: 0:03:54  lr: 0.005000  loss: 0.5270 (0.5213)  loss_classifier: 0.1935 (0.1894)  loss_box_reg: 0.1785 (0.1794)  loss_objectness: 0.0312 (0.0318)  loss_rpn_box_reg: 0.1226 (0.1207)  time: 2.0240  data: 0.1009  max mem: 11737
# Epoch: [2]  [110/209]  eta: 0:03:32  lr: 0.005000  loss: 0.5353 (0.5215)  loss_classifier: 0.1911 (0.1893)  loss_box_reg: 0.1865 (0.1791)  loss_objectness: 0.0340 (0.0323)  loss_rpn_box_reg: 0.1226 (0.1208)  time: 2.0613  data: 0.1057  max mem: 11737
# Epoch: [2]  [120/209]  eta: 0:03:09  lr: 0.005000  loss: 0.5132 (0.5219)  loss_classifier: 0.1891 (0.1897)  loss_box_reg: 0.1784 (0.1792)  loss_objectness: 0.0346 (0.0324)  loss_rpn_box_reg: 0.1184 (0.1206)  time: 2.0651  data: 0.1067  max mem: 11737
# Epoch: [2]  [130/209]  eta: 0:02:48  lr: 0.005000  loss: 0.5132 (0.5215)  loss_classifier: 0.1891 (0.1894)  loss_box_reg: 0.1784 (0.1792)  loss_objectness: 0.0325 (0.0324)  loss_rpn_box_reg: 0.1155 (0.1204)  time: 2.0498  data: 0.1019  max mem: 11737
# Epoch: [2]  [140/209]  eta: 0:02:26  lr: 0.005000  loss: 0.5337 (0.5234)  loss_classifier: 0.1947 (0.1905)  loss_box_reg: 0.1783 (0.1797)  loss_objectness: 0.0325 (0.0324)  loss_rpn_box_reg: 0.1208 (0.1208)  time: 2.0599  data: 0.1004  max mem: 11737
# Epoch: [2]  [150/209]  eta: 0:02:04  lr: 0.005000  loss: 0.5519 (0.5246)  loss_classifier: 0.2017 (0.1907)  loss_box_reg: 0.1904 (0.1803)  loss_objectness: 0.0335 (0.0327)  loss_rpn_box_reg: 0.1237 (0.1209)  time: 2.0289  data: 0.1032  max mem: 11737
# Epoch: [2]  [160/209]  eta: 0:01:43  lr: 0.005000  loss: 0.5316 (0.5243)  loss_classifier: 0.1912 (0.1907)  loss_box_reg: 0.1766 (0.1801)  loss_objectness: 0.0318 (0.0327)  loss_rpn_box_reg: 0.1187 (0.1208)  time: 2.0281  data: 0.1070  max mem: 11737
# Epoch: [2]  [170/209]  eta: 0:01:22  lr: 0.005000  loss: 0.5205 (0.5240)  loss_classifier: 0.1883 (0.1905)  loss_box_reg: 0.1766 (0.1803)  loss_objectness: 0.0300 (0.0325)  loss_rpn_box_reg: 0.1156 (0.1207)  time: 2.0503  data: 0.1013  max mem: 11737
# Epoch: [2]  [180/209]  eta: 0:01:01  lr: 0.005000  loss: 0.5131 (0.5229)  loss_classifier: 0.1884 (0.1901)  loss_box_reg: 0.1773 (0.1799)  loss_objectness: 0.0285 (0.0323)  loss_rpn_box_reg: 0.1156 (0.1205)  time: 2.0469  data: 0.0974  max mem: 11737
# Epoch: [2]  [190/209]  eta: 0:00:39  lr: 0.005000  loss: 0.5055 (0.5225)  loss_classifier: 0.1843 (0.1899)  loss_box_reg: 0.1773 (0.1799)  loss_objectness: 0.0285 (0.0323)  loss_rpn_box_reg: 0.1166 (0.1204)  time: 2.0488  data: 0.0995  max mem: 11737
# Epoch: [2]  [200/209]  eta: 0:00:18  lr: 0.005000  loss: 0.5198 (0.5228)  loss_classifier: 0.1830 (0.1898)  loss_box_reg: 0.1792 (0.1800)  loss_objectness: 0.0309 (0.0324)  loss_rpn_box_reg: 0.1185 (0.1206)  time: 2.0585  data: 0.1212  max mem: 11737
# Epoch: [2]  [208/209]  eta: 0:00:02  lr: 0.005000  loss: 0.5081 (0.5218)  loss_classifier: 0.1824 (0.1895)  loss_box_reg: 0.1762 (0.1797)  loss_objectness: 0.0344 (0.0324)  loss_rpn_box_reg: 0.1181 (0.1203)  time: 1.9171  data: 0.1065  max mem: 11737
# Epoch: [2] Total time: 0:07:15 (2.0838 s / it)
# creating index...
# index created!
# Test:  [0/4]  eta: 0:00:28  model_time: 0.6636 (0.6636)  evaluator_time: 2.8840 (2.8840)  time: 7.2188  data: 3.5493  max mem: 11737
# Test:  [3/4]  eta: 0:00:03  model_time: 0.6320 (0.5106)  evaluator_time: 2.6108 (2.1544)  time: 3.6866  data: 0.9282  max mem: 11737
# Test: Total time: 0:00:14 (3.7039 s / it)
# Averaged stats: model_time: 0.6320 (0.5106)  evaluator_time: 2.6108 (2.1544)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.515
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.924
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.515
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.097
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.506
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.568
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.016
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.148
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.574
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.168
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.569
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.616
# Epoch: [3]  [  0/209]  eta: 0:26:55  lr: 0.000500  loss: 0.4460 (0.4460)  loss_classifier: 0.1644 (0.1644)  loss_box_reg: 0.1639 (0.1639)  loss_objectness: 0.0189 (0.0189)  loss_rpn_box_reg: 0.0989 (0.0989)  time: 7.7288  data: 5.1869  max mem: 11737
# Epoch: [3]  [ 10/209]  eta: 0:09:17  lr: 0.000500  loss: 0.5392 (0.5243)  loss_classifier: 0.1928 (0.1912)  loss_box_reg: 0.1837 (0.1788)  loss_objectness: 0.0285 (0.0312)  loss_rpn_box_reg: 0.1252 (0.1231)  time: 2.8039  data: 0.6328  max mem: 11737
# Epoch: [3]  [ 20/209]  eta: 0:07:37  lr: 0.000500  loss: 0.5272 (0.5194)  loss_classifier: 0.1926 (0.1913)  loss_box_reg: 0.1805 (0.1786)  loss_objectness: 0.0287 (0.0299)  loss_rpn_box_reg: 0.1218 (0.1197)  time: 2.1567  data: 0.1370  max mem: 11737
# Epoch: [3]  [ 30/209]  eta: 0:06:50  lr: 0.000500  loss: 0.4938 (0.5060)  loss_classifier: 0.1793 (0.1862)  loss_box_reg: 0.1737 (0.1754)  loss_objectness: 0.0287 (0.0288)  loss_rpn_box_reg: 0.1134 (0.1155)  time: 2.0146  data: 0.0969  max mem: 11737
# Epoch: [3]  [ 40/209]  eta: 0:06:19  lr: 0.000500  loss: 0.4905 (0.5089)  loss_classifier: 0.1761 (0.1863)  loss_box_reg: 0.1752 (0.1769)  loss_objectness: 0.0287 (0.0289)  loss_rpn_box_reg: 0.1141 (0.1168)  time: 2.0601  data: 0.1030  max mem: 11737
# Epoch: [3]  [ 50/209]  eta: 0:05:51  lr: 0.000500  loss: 0.5195 (0.5106)  loss_classifier: 0.1850 (0.1862)  loss_box_reg: 0.1793 (0.1777)  loss_objectness: 0.0287 (0.0289)  loss_rpn_box_reg: 0.1205 (0.1178)  time: 2.0815  data: 0.1139  max mem: 11737
# Epoch: [3]  [ 60/209]  eta: 0:05:24  lr: 0.000500  loss: 0.4972 (0.5059)  loss_classifier: 0.1827 (0.1851)  loss_box_reg: 0.1770 (0.1760)  loss_objectness: 0.0265 (0.0282)  loss_rpn_box_reg: 0.1121 (0.1165)  time: 2.0434  data: 0.1100  max mem: 11737
# Epoch: [3]  [ 70/209]  eta: 0:05:01  lr: 0.000500  loss: 0.4894 (0.5042)  loss_classifier: 0.1817 (0.1845)  loss_box_reg: 0.1664 (0.1751)  loss_objectness: 0.0248 (0.0279)  loss_rpn_box_reg: 0.1121 (0.1167)  time: 2.0713  data: 0.1052  max mem: 11737
# Epoch: [3]  [ 80/209]  eta: 0:04:38  lr: 0.000500  loss: 0.4956 (0.5031)  loss_classifier: 0.1805 (0.1843)  loss_box_reg: 0.1664 (0.1743)  loss_objectness: 0.0248 (0.0280)  loss_rpn_box_reg: 0.1132 (0.1165)  time: 2.1024  data: 0.1113  max mem: 11737
# Epoch: [3]  [ 90/209]  eta: 0:04:15  lr: 0.000500  loss: 0.4949 (0.5026)  loss_classifier: 0.1809 (0.1838)  loss_box_reg: 0.1669 (0.1744)  loss_objectness: 0.0264 (0.0280)  loss_rpn_box_reg: 0.1139 (0.1165)  time: 2.0673  data: 0.1100  max mem: 11737
# Epoch: [3]  [100/209]  eta: 0:03:54  lr: 0.000500  loss: 0.4912 (0.5030)  loss_classifier: 0.1814 (0.1842)  loss_box_reg: 0.1714 (0.1744)  loss_objectness: 0.0249 (0.0278)  loss_rpn_box_reg: 0.1159 (0.1165)  time: 2.1006  data: 0.1086  max mem: 11737
# Epoch: [3]  [110/209]  eta: 0:03:31  lr: 0.000500  loss: 0.4943 (0.5010)  loss_classifier: 0.1809 (0.1836)  loss_box_reg: 0.1747 (0.1738)  loss_objectness: 0.0257 (0.0278)  loss_rpn_box_reg: 0.1141 (0.1159)  time: 2.0995  data: 0.1061  max mem: 11737
# Epoch: [3]  [120/209]  eta: 0:03:09  lr: 0.000500  loss: 0.4999 (0.5009)  loss_classifier: 0.1799 (0.1836)  loss_box_reg: 0.1732 (0.1735)  loss_objectness: 0.0268 (0.0279)  loss_rpn_box_reg: 0.1141 (0.1159)  time: 2.0445  data: 0.1007  max mem: 11737
# Epoch: [3]  [130/209]  eta: 0:02:48  lr: 0.000500  loss: 0.5039 (0.5003)  loss_classifier: 0.1816 (0.1833)  loss_box_reg: 0.1728 (0.1735)  loss_objectness: 0.0268 (0.0281)  loss_rpn_box_reg: 0.1123 (0.1154)  time: 2.0802  data: 0.1152  max mem: 11737
# Epoch: [3]  [140/209]  eta: 0:02:26  lr: 0.000500  loss: 0.4746 (0.4988)  loss_classifier: 0.1751 (0.1827)  loss_box_reg: 0.1625 (0.1728)  loss_objectness: 0.0268 (0.0280)  loss_rpn_box_reg: 0.1075 (0.1152)  time: 2.1110  data: 0.1165  max mem: 11737
# Epoch: [3]  [150/209]  eta: 0:02:05  lr: 0.000500  loss: 0.4758 (0.4982)  loss_classifier: 0.1803 (0.1827)  loss_box_reg: 0.1677 (0.1725)  loss_objectness: 0.0254 (0.0281)  loss_rpn_box_reg: 0.1076 (0.1150)  time: 2.0923  data: 0.1005  max mem: 11737
# Epoch: [3]  [160/209]  eta: 0:01:44  lr: 0.000500  loss: 0.4984 (0.4984)  loss_classifier: 0.1818 (0.1826)  loss_box_reg: 0.1723 (0.1725)  loss_objectness: 0.0278 (0.0283)  loss_rpn_box_reg: 0.1110 (0.1149)  time: 2.0952  data: 0.1032  max mem: 11737
# Epoch: [3]  [170/209]  eta: 0:01:22  lr: 0.000500  loss: 0.5059 (0.4989)  loss_classifier: 0.1809 (0.1829)  loss_box_reg: 0.1726 (0.1727)  loss_objectness: 0.0299 (0.0284)  loss_rpn_box_reg: 0.1139 (0.1150)  time: 2.0876  data: 0.1025  max mem: 11737
# Epoch: [3]  [180/209]  eta: 0:01:01  lr: 0.000500  loss: 0.4920 (0.4981)  loss_classifier: 0.1820 (0.1827)  loss_box_reg: 0.1669 (0.1724)  loss_objectness: 0.0274 (0.0282)  loss_rpn_box_reg: 0.1146 (0.1148)  time: 2.0937  data: 0.1026  max mem: 11737
# Epoch: [3]  [190/209]  eta: 0:00:40  lr: 0.000500  loss: 0.4960 (0.4984)  loss_classifier: 0.1802 (0.1826)  loss_box_reg: 0.1671 (0.1724)  loss_objectness: 0.0268 (0.0283)  loss_rpn_box_reg: 0.1190 (0.1150)  time: 2.1022  data: 0.1042  max mem: 11737
# Epoch: [3]  [200/209]  eta: 0:00:19  lr: 0.000500  loss: 0.5035 (0.4989)  loss_classifier: 0.1785 (0.1828)  loss_box_reg: 0.1753 (0.1726)  loss_objectness: 0.0299 (0.0284)  loss_rpn_box_reg: 0.1166 (0.1151)  time: 2.0757  data: 0.0994  max mem: 11737
# Epoch: [3]  [208/209]  eta: 0:00:02  lr: 0.000500  loss: 0.5035 (0.4985)  loss_classifier: 0.1799 (0.1826)  loss_box_reg: 0.1736 (0.1724)  loss_objectness: 0.0296 (0.0283)  loss_rpn_box_reg: 0.1166 (0.1152)  time: 1.9063  data: 0.0873  max mem: 11737
# Epoch: [3] Total time: 0:07:19 (2.1007 s / it)
# creating index...
# index created!
# Test:  [0/4]  eta: 0:00:29  model_time: 0.6426 (0.6426)  evaluator_time: 2.8566 (2.8566)  time: 7.2983  data: 3.6789  max mem: 11737
# Test:  [3/4]  eta: 0:00:03  model_time: 0.6335 (0.5073)  evaluator_time: 2.5874 (2.2178)  time: 3.7557  data: 0.9367  max mem: 11737
# Test: Total time: 0:00:15 (3.7825 s / it)
# Averaged stats: model_time: 0.6335 (0.5073)  evaluator_time: 2.5874 (2.2178)
# Accumulating evaluation results...
# DONE (t=0.08s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.516
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.924
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.517
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.123
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.506
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.580
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.016
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.148
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.575
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.168
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.567
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.627

# %% [markdown]
# ## Final Prediction

# %%
DETECTION_THRESHOLD = 0.40

# %%
model.eval()

results = []

for image_ids, images in test_data_loader:

    images = list(image.to(DEVICE) for image in images)
    outputs = model(images)

    for i, image in enumerate(images):

        boxes = outputs[i]['boxes'].data.cpu().numpy()
        scores = outputs[i]['scores'].data.cpu().numpy()
        
        boxes = boxes[scores >= DETECTION_THRESHOLD].astype(np.int32)
        scores = scores[scores >= DETECTION_THRESHOLD]
        image_id = image_ids[i]
        
        boxes[:, 2] = boxes[:, 2] - boxes[:, 0]
        boxes[:, 3] = boxes[:, 3] - boxes[:, 1]
        
        result = {
            'image_id': image_id,
            'PredictionString': format_prediction_string(boxes, scores)
        }
        results.append(result)

# %%
# !rm -rf *

# %%
sub_df = pd.DataFrame(results)
sub_df.to_csv('submission.csv', index=False)
sub_df.head()
# Out:
#     image_id                                   PredictionString
# 0  796707dd7  0.9903 711 828 102 93 0.9901 507 786 87 89 0.9...
# 1  cc3532ff6  0.9977 263 640 102 162 0.9975 555 831 124 175 ...
# 2  51f1be19e  0.9922 279 472 131 117 0.9920 605 83 158 171 0...
# 3  51b3e36ab  0.9977 538 28 252 136 0.9974 868 286 154 142 0...
# 4  f5a1f0358  0.9958 147 759 149 111 0.9943 289 457 160 102 ...

# %%
def get_bboxes(pred_str):
    span=5
    preds = pred_str.split()
    bboxes = [list(map(int, preds[i+1:i+span] )) for i in range(0, len(preds), span)]
    return bboxes

# %%
for image_id, pred_str in zip(sub_df.iloc[:3]['image_id'], sub_df.iloc[:3]['PredictionString']):
    image_path = os.path.join(DATA_DIR, 'test', f'{image_id}.jpg')
    image = cv2.imread(image_path, cv2.IMREAD_COLOR)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB).astype(np.float32)
    image /= 255.0
    boxes = get_bboxes(pred_str)
    
    fig, ax = plt.subplots(1, 1, figsize=(16, 8))

    for box in boxes:
        cv2.rectangle(image,
                      (box[0], box[1]),
                      (box[2] + box[0], box[3] + box[1]),
                      (255, 0, 0), 3)

    ax.set_axis_off()
    ax.imshow(image)
    plt.show()
